# %%
import pandas as pd

# %%
df = pd.read_csv('full_results2.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2206 entries, 0 to 2205
# Data columns (total 18 columns):
# authors           2008 non-null object
# calories          1937 non-null object
# carbs             1934 non-null object
# cholesterol       1607 non-null object
# description       2086 non-null object
# fat               1936 non-null object
# fiber             1912 non-null object
# ingredients       2206 non-null object
# make_again_pct    2206 non-null object
# name              2206 non-null object
# num_reviews       2206 non-null object
# num_servings      2144 non-null object
# protein           1936 non-null object
# rating            2206 non-null object
# recipe_steps      2206 non-null object
# saturated_fat     1937 non-null object
# sodium            1937 non-null object
# tags              2170 non-null object
# dtypes: object(18)
# memory usage: 310.3+ KB

# %%
def convert_to_list(x):
    if x:
        return x.split(',')

df['tags'] = df['tags'].apply(convert_to_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-c64b0a68cdaa> in <module>
# ----> 1 df['tags'] = df['tags'].apply(lambda x: x.split(','))
#
# ~/anaconda3/envs/webscraping/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-7-c64b0a68cdaa> in <lambda>(x)
# ----> 1 df['tags'] = df['tags'].apply(lambda x: x.split(','))
#
# AttributeError: 'float' object has no attribute 'split'

# %%
df.head()
# Out:
#                    authors calories      carbs  cholesterol  \
# 0            Scott Peacock      219  30 g(10%)          NaN
# 1  Marge Perry,David Bonom      451  85 g(28%)          NaN
# 2  Marge Perry,David Bonom      753  97 g(32%)   72 mg(24%)
# 3             Kat Boytsova      604  98 g(33%)   95 mg(32%)
# 4           Anna Stockwell      573  42 g(14%)  137 mg(46%)
#
#                                          description        fat      fiber  \
# 0  Eye-opening notes of lemon, lime, and grapefru...    0 g(0%)    1 g(5%)
# 1  Our kids don’t want to hear the story again ab...    5 g(7%)  17 g(70%)
# 2  This is the hearty pasta dish that everyone lo...  22 g(34%)  11 g(42%)
# 3       After seeing the cinnamon roll from Paris's   20 g(31%)   4 g(15%)
# 4  Sweet peas, pea shoots, and a sprinkle of lemo...  31 g(48%)   8 g(30%)
#
#                                          ingredients make_again_pct  \
# 0  1/2 cup sugar,1/2 cup water,1 cup white grape ...           100%
# ...
