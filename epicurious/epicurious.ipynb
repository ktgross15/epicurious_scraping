# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('full_results.csv')

# %%
df.to_csv('~/Desktop/raw_epicurious.csv', index=False)

# %%
len(df)
# Out:
# 29732

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29732 entries, 0 to 29731
# Data columns (total 20 columns):
# active_time       6573 non-null object
# authors           13092 non-null object
# calories          23285 non-null float64
# carbs             23270 non-null object
# cholesterol       18899 non-null object
# description       22326 non-null object
# fat               23261 non-null object
# fiber             23016 non-null object
# ingredients       29691 non-null object
# make_again_pct    29710 non-null object
# name              29732 non-null object
# num_reviews       29732 non-null int64
# num_servings      28751 non-null object
# protein           23271 non-null object
# rating            29710 non-null object
# recipe_steps      29725 non-null object
# saturated_fat     23255 non-null object
# sodium            23284 non-null object
# tags              29139 non-null object
# total_time        6939 non-null object
# dtypes: float64(1), int64(1), object(18)
# ...

# %%
df.head()
# Out:
#          active_time                  authors  calories      carbs  \
# 0                NaN  Marge Perry,David Bonom     451.0  85 g(28%)
# 1                NaN  Marge Perry,David Bonom     753.0  97 g(32%)
# 2  1 hour 10 minutes             Kat Boytsova     604.0  98 g(33%)
# 3             45 min                      NaN       NaN        NaN
# 4         45 minutes           Anna Stockwell    1070.0  71 g(24%)
#
#     cholesterol                                        description        fat  \
# 0           NaN  Our kids don’t want to hear the story again ab...    5 g(7%)
# 1    72 mg(24%)  This is the hearty pasta dish that everyone lo...  22 g(34%)
# 2    95 mg(32%)       After seeing the cinnamon roll from Paris's   20 g(31%)
# 3           NaN  This is a dessert you'll make over and over in...        NaN
# 4  307 mg(102%)  This is not your grandma’s beef stroganoff. We...  64 g(99%)
#
#        fiber                                        ingredients  \
# ...

# %%
def convert_to_list(x):
    if type(x)!=float:
        return x.split(',')

# %%
df['tags'] = df['tags'].apply(convert_to_list)
df['authors'] = df['authors'].apply(convert_to_list)
# df['ingredients'] = df['ingredients'].apply(convert_to_list)

# %%
df['site'] = 'Epicurious'

# %%
df = df[['name','site','authors','description','ingredients','recipe_steps','tags','calories','carbs','fat',
          'protein','saturated_fat','sodium','fiber','cholesterol','num_servings','num_reviews',
          'make_again_pct','rating']]

# %%
df.head()
# Out:
#                               name        site                     authors  \
# 0  Sheet-Pan Cuban Rice and Beans   Epicurious  [Marge Perry, David Bonom]
# 1        Rigatoni with Meat Sauce   Epicurious  [Marge Perry, David Bonom]
# 2   Glazed Cinnamon-Cardamom Buns   Epicurious              [Kat Boytsova]
# 3         Apple and Calvados Tart   Epicurious                        None
# 4                Steak Stroganoff   Epicurious            [Anna Stockwell]
#
#                                          description  \
# 0  Our kids don’t want to hear the story again ab...
# 1  This is the hearty pasta dish that everyone lo...
# 2       After seeing the cinnamon roll from Paris's
# 3  This is a dessert you'll make over and over in...
# 4  This is not your grandma’s beef stroganoff. We...
#
#                                          ingredients  \
# 0  [2 bell peppers,  assorted colors,  cut into t...
# 1  [2 tablespoons extra virgin olive oil, 1 mediu...
# ...

# %%
df.to_csv('~/Desktop/epicurious.csv', index=False)
